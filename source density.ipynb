# %%
import scipy.special as sp
import numpy as np
import matplotlib.pyplot as plt

r = 1 # m
omega = 2*np.pi*440 #Hz
c = 343 # m/s
t = np.linspace(-np.pi/2, np.pi/2, 100)
plt.plot(t, np.array([ sp.jv(0, omega*r/c* np.sin(theta)) for theta in t ])**2)
